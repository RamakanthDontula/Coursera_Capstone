# %% [markdown]
# # Capstone Project - Student Hostel Near Engineering Colleges in Hyderabad

# %% [markdown]
# # Introduction / Business Problem

# %% [markdown]
# Hyderabad is the capital and largest city of the South Indian state of Telangana. It has a population of over 20 million people spread across 650 square kilometres. Being one of the top IT services companies’ destination in the country and offering ample employment opportunities has resulted in Hyderabad being home to 131 engineering colleges and thus attracting thousands of students from across the country.
#
# With scores of students flocking the city from across the country and near by towns & cities, the demand for student accomodation has gradually increased. Sensing a lucrative business opportunity, one of my friends is interested in setting up a student hostel near engineering colleges and tasked me with zeroing on an area with highest density of engineering college, so that he has a steady supply of occupants for his hostel.
#
# Through this project I would be exploring Hyderabad for engineering colleges and find area/neighbourhood with highest density of engineering colleges.

# %% [markdown]
# # Data Section

# %% [markdown]
# Firstly, I obtained postal code details all the localities of Hyderabad. The data was extracted using the below python library:

# %% [markdown]
# There is a python library pgeocode (https://github.com/symerio/pgeocode) which is high performance off-line querying of GPS coordinates, region name and municipality name from postal codes. Distances between postal codes as well as general distance queries are also supported. The used GeoNames database includes postal codes for 83 countries.
# In this library I used ' index postal_codes' function which creates a data frame of unique postal codes of a given country.
#
# The data frame consists of following columns:

# %% [markdown]
#     •	country code: iso country code, 2 characters
#     •	postal code: postal code
#     •	place name: place name (e.g. town, city etc)
#     •	state_name: 1. order subdivision (state)
#     •	state_code: 1. order subdivision (state)
#     •	county_name: 2. order subdivision (county/province)
#     •	county_code: 2. order subdivision (county/province)
#     •	community_name: 3. order subdivision (community)
#     •	community_code: 3. order subdivision (community)
#     •	latitude: estimated latitude (wgs84)
#     •	longitude: estimated longitude (wgs84)
#     •	accuracy: accuracy of lat/lng from 1=estimated to 6=centroid

# %% [markdown]
# Since images are not shown in github, here is the link (https://github.com/RamakanthDontula/Coursera_Capstone/blob/master/Hyd%20Loc%20Code.png)

# %% [markdown]
# Secondly, I needed list of engineering colleges in Hyderabad. Luckily, these were already available at https://en.wikipedia.org/wiki/List_of_engineering_colleges_in_Telangana

# %% [markdown]
# Lastly, I merged localities data with engineering colleges data on Locality to get Lat, Lon values for engineering colleges.

# %% [markdown]
# Data Wrangling like dropping unnecessary columns, blank values and duplicate rows were done to ge the desired data frame.

# %% [markdown]
# ## Methodology

# %% [markdown]
# Geo location codes of all the localities of Hyderabad are pulled using pgeocode library
#
# Engineering colleges in Hyderabad data was collected from https://en.wikipedia.org/wiki/List_of_engineering_colleges_in_Telangana and cleaned and processed into a dataframe.
#
# FourSquare be used to locate all areas in the city. Engineering Colleges details with geolocation data is added to the dataframe.
#
# Data is processed to calculate additional values like engineering colleges density in each locality
#
# Finally, the data is visually plotted using graphing from various Python libraries.

# %% [markdown]
# ## Code

# %% [markdown]
# ### 1. Importing Necessary Libraries

# %%
# !pip install lxml
# !pip install pgeocode
# !pip install geopy
import pandas as pd
import pgeocode
import requests
from geopy.geocoders import Nominatim
# Out:
# Requirement already satisfied: lxml in /opt/conda/envs/Python36/lib/python3.6/site-packages (4.3.1)
# Collecting pgeocode
#   Downloading https://files.pythonhosted.org/packages/86/44/519e3db3db84acdeb29e24f2e65991960f13464279b61bde5e9e96909c9d/pgeocode-0.2.1-py2.py3-none-any.whl
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pgeocode) (2.21.0)
# Requirement already satisfied: numpy in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pgeocode) (1.15.4)
# Requirement already satisfied: pandas in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pgeocode) (0.24.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->pgeocode) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->pgeocode) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->pgeocode) (2019.11.28)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->pgeocode) (1.24.1)
# Requirement already satisfied: python-dateutil>=2.5.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pandas->pgeocode) (2.7.5)
# Requirement already satisfied: pytz>=2011k in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pandas->pgeocode) (2018.9)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from python-dateutil>=2.5.0->pandas->pgeocode) (1.12.0)
# Installing collected packages: pgeocode
# Successfully installed pgeocode-0.2.1
# Requirement already satisfied: geopy in /opt/conda/envs/Python36/lib/python3.6/site-packages (1.18.1)
# Requirement already satisfied: geographiclib<2,>=1.49 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geopy) (1.49)

# %% [markdown]
# ### 2. Scraping the web for the list of Enigneering Colleges

# %%
# Scraping the web page
df=pd.read_html("https://en.wikipedia.org/wiki/List_of_engineering_colleges_in_Telangana")[0]

# %%
df.head()
# Out:
#     Short Name                                          Full Name  \
# 0        ACEEC                            ACE Engineering College
# 1        Mrits  Malla reddy institution of technology and science
# 2  RGUKT-Basar  Rajiv Gandhi University of Knowledge Technologies
# 3         VBIT           Vignana Bharathi Institute of technology
# 4         AURP                       Aurora Group of Institutions
#
#                    Website ! Est. Year Affiliated University  \
# 0  https://www.aceec.ac.in        2007       JNTU, Hyderabad
# 1  https://www.mrits.ac.in        2005       JNTU, Hyderabad
# 2  http://www.rgukt.ac.in/        2008            Autonomous
# 3   http://vbithyd.ac.in//        2004            Autonomous
# 4    http://www.aurora.in/        1989       JNTU, Hyderabad
#
#           Revenue Division            District  Ownership  \
# 0               Ankushapur  Medchal-Malkajgiri  [Private]
# 1  masimmagudha,dhulapally  Medchal-Malkajgiri  [Private]
# 2                    Basar              Nirmal     Public
# 3                Ghatkesar  Medchal-Malkajgiri  [Private]
# 4                Ghatkesar  Medchal-Malkajgiri  [Private]
#
#             Additional information  Unnamed: 9
# 0  With a Difference in Excellence         NaN
# 1                              NaN         NaN
# 2                              NaN         NaN
# 3                              NaN         NaN
# 4                              NaN         NaN

# %%
df.drop(['Short Name', 'Website', '! Est. Year', 'Affiliated University', 'Ownership', 'Additional information', 'Unnamed: 9'], axis=1, inplace=True)

# %%
df.head()
# Out:
#                                            Full Name         Revenue Division  \
# 0                            ACE Engineering College               Ankushapur
# 1  Malla reddy institution of technology and science  masimmagudha,dhulapally
# 2  Rajiv Gandhi University of Knowledge Technologies                    Basar
# 3           Vignana Bharathi Institute of technology                Ghatkesar
# 4                       Aurora Group of Institutions                Ghatkesar
#
#              District
# 0  Medchal-Malkajgiri
# 1  Medchal-Malkajgiri
# 2              Nirmal
# 3  Medchal-Malkajgiri
# 4  Medchal-Malkajgiri

# %%
df.rename(columns={'Full Name':'College','Revenue Division':'Locality'}, inplace=True)

# %%
df.head()
# Out:
#                                              College                 Locality  \
# 0                            ACE Engineering College               Ankushapur
# 1  Malla reddy institution of technology and science  masimmagudha,dhulapally
# 2  Rajiv Gandhi University of Knowledge Technologies                    Basar
# 3           Vignana Bharathi Institute of technology                Ghatkesar
# 4                       Aurora Group of Institutions                Ghatkesar
#
#              District
# 0  Medchal-Malkajgiri
# 1  Medchal-Malkajgiri
# 2              Nirmal
# 3  Medchal-Malkajgiri
# 4  Medchal-Malkajgiri

# %%
#getting lAt, Lon values of localities in Hyderabad City
country = pgeocode.Nominatim('in')
Postcode = country._index_postal_codes()
Telangana = Postcode[Postcode.state_name == 'Telangana']
HydLoc = Telangana[Telangana.county_name == 'Hyderabad']
HydLoc.head()
# Out:
#      country code postal_code  \
# 8286           IN      500001
# 8287           IN      500002
# 8288           IN      500003
# 8289           IN      500004
# 8290           IN      500005
#
#                                              place_name state_name  \
# 8286  Gandhi Bhawan (Hyderabad), Moazzampura, Hydera...  Telangana
# 8287                  Hyderabad Jubilee H.O, Moghalpura  Telangana
# 8288                         Kingsway, Secunderabad H.O  Telangana
# 8289  Bazarghat (Hyderabad), Khairatabad H.O, Parish...  Telangana
# 8290  Jalapally, Crp Camp (Hyderabad), Keshogiri, Ba...  Telangana
#
#       state_code county_name  county_code community_name  community_code  \
# 8286          40   Hyderabad        536.0       Nampally             NaN
# 8287          40   Hyderabad        536.0      Charminar             NaN
# 8288          40   Hyderabad        536.0   Secunderabad             NaN
# 8289          40   Hyderabad        536.0    Khairatabad             NaN
# 8290          40   Hyderabad        536.0      Hyderabad             NaN
#
#       latitude  longitude  accuracy
# 8286   17.3862    78.4620         1
# 8287   17.3862    78.4620         1
# 8288   17.3862    78.4620         1
# 8289   17.3872    78.4621         4
# 8290   17.3102    78.4997         3

# %%
HydLoc.shape
# Out:
# (104, 12)

# %%
#Dropping unnecessary columns
HydLoc.drop(['country code', 'postal_code','place_name','state_name','state_code', 'county_name', 'county_code','community_code','accuracy'], axis=1, inplace=True)
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
HydLoc.head()
# Out:
#      community_name  latitude  longitude
# 8286       Nampally   17.3862    78.4620
# 8287      Charminar   17.3862    78.4620
# 8288   Secunderabad   17.3862    78.4620
# 8289    Khairatabad   17.3872    78.4621
# 8290      Hyderabad   17.3102    78.4997

# %%
HydLoc.rename(columns={'community_name':'Locality'}, inplace=True)
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
#Merging Hyderbad localities to colleged list for lat, lon values for colleges 
HydMerge = pd.merge(df, HydLoc, on='Locality')

# %%
HydMerge.head()
# Out:
#                                              College   Locality  \
# 0           Vignana Bharathi Institute of technology  Ghatkesar
# 1           Vignana Bharathi Institute of technology  Ghatkesar
# 2                       Aurora Group of Institutions  Ghatkesar
# 3                       Aurora Group of Institutions  Ghatkesar
# 4  Vignan Institute of management and technology ...  Ghatkesar
#
#              District  latitude  longitude
# 0  Medchal-Malkajgiri   17.3535    78.2402
# 1  Medchal-Malkajgiri   17.3898    78.4699
# 2  Medchal-Malkajgiri   17.3535    78.2402
# 3  Medchal-Malkajgiri   17.3898    78.4699
# 4  Medchal-Malkajgiri   17.3535    78.2402

# %%
HydMerge.shape
# Out:
# (73, 5)

# %%
HydMerge.head(30)
# Out:
#                                               College   Locality  \
# 0            Vignana Bharathi Institute of technology  Ghatkesar
# 1            Vignana Bharathi Institute of technology  Ghatkesar
# 2                        Aurora Group of Institutions  Ghatkesar
# 3                        Aurora Group of Institutions  Ghatkesar
# 4   Vignan Institute of management and technology ...  Ghatkesar
# 5   Vignan Institute of management and technology ...  Ghatkesar
# 6   Princeton Institute of engineering and technology  Ghatkesar
# 7   Princeton Institute of engineering and technology  Ghatkesar
# 8               Nalla Malla Reddy Engineering College  Ghatkesar
# 9               Nalla Malla Reddy Engineering College  Ghatkesar
# 10  Megha Institute of Engineering and Technology ...  Ghatkesar
# 11  Megha Institute of Engineering and Technology ...  Ghatkesar
# 12                     Indian Institute of Technology  Hyderabad
# 13                     Indian Institute of Technology  Hyderabad
# 14                     Indian Institute of Technology  Hyderabad
# 15                     Indian Institute of Technology  Hyderabad
# 16                     Indian Institute of Technology  Hyderabad
# 17                     Indian Institute of Technology  Hyderabad
# 18                                 Osmania University  Hyderabad
# 19                                 Osmania University  Hyderabad
# 20                                 Osmania University  Hyderabad
# 21                                 Osmania University  Hyderabad
# 22                                 Osmania University  Hyderabad
# 23                                 Osmania University  Hyderabad
# 24  VNR Vignana Jyothi Institute of Engineering an...  Hyderabad
# 25  VNR Vignana Jyothi Institute of Engineering an...  Hyderabad
# 26  VNR Vignana Jyothi Institute of Engineering an...  Hyderabad
# 27  VNR Vignana Jyothi Institute of Engineering an...  Hyderabad
# 28  VNR Vignana Jyothi Institute of Engineering an...  Hyderabad
# 29  VNR Vignana Jyothi Institute of Engineering an...  Hyderabad
#
#               District  latitude  longitude
# 0   Medchal-Malkajgiri   17.3535   78.24020
# 1   Medchal-Malkajgiri   17.3898   78.46990
# 2   Medchal-Malkajgiri   17.3535   78.24020
# 3   Medchal-Malkajgiri   17.3898   78.46990
# 4   Medchal-Malkajgiri   17.3535   78.24020
# 5   Medchal-Malkajgiri   17.3898   78.46990
# 6   Medchal-Malkajgiri   17.3535   78.24020
# 7   Medchal-Malkajgiri   17.3898   78.46990
# 8   Medchal-Malkajgiri   17.3535   78.24020
# 9   Medchal-Malkajgiri   17.3898   78.46990
# 10  Medchal-Malkajgiri   17.3535   78.24020
# 11  Medchal-Malkajgiri   17.3898   78.46990
# 12          Sangareddy   17.3102   78.49970
# 13          Sangareddy   17.3939   78.45290
# 14          Sangareddy   17.4058   78.55910
# 15          Sangareddy   17.3724   78.43700
# 16          Sangareddy   17.3898   78.51375
# 17          Sangareddy   17.5902   78.66680
# 18           Hyderabad   17.3102   78.49970
# 19           Hyderabad   17.3939   78.45290
# 20           Hyderabad   17.4058   78.55910
# 21           Hyderabad   17.3724   78.43700
# 22           Hyderabad   17.3898   78.51375
# 23           Hyderabad   17.5902   78.66680
# 24  Medchal-Malkajgiri   17.3102   78.49970
# 25  Medchal-Malkajgiri   17.3939   78.45290
# 26  Medchal-Malkajgiri   17.4058   78.55910
# 27  Medchal-Malkajgiri   17.3724   78.43700
# 28  Medchal-Malkajgiri   17.3898   78.51375
# 29  Medchal-Malkajgiri   17.5902   78.66680

# %%
#Dropping duplicates
HydCollege = HydMerge.drop_duplicates(['College'])

# %%
HydCollege.shape
# Out:
# (25, 5)

# %%
HydCollege.head()
# Out:
#                                              College   Locality  \
# 0           Vignana Bharathi Institute of technology  Ghatkesar
# 2                       Aurora Group of Institutions  Ghatkesar
# 4  Vignan Institute of management and technology ...  Ghatkesar
# 6  Princeton Institute of engineering and technology  Ghatkesar
# 8              Nalla Malla Reddy Engineering College  Ghatkesar
#
#              District  latitude  longitude
# 0  Medchal-Malkajgiri   17.3535    78.2402
# 2  Medchal-Malkajgiri   17.3535    78.2402
# 4  Medchal-Malkajgiri   17.3535    78.2402
# 6  Medchal-Malkajgiri   17.3535    78.2402
# 8  Medchal-Malkajgiri   17.3535    78.2402

# %%
HydCollege_Final = HydCollege.reset_index(drop=True)

# %%
HydCollege_Final.head()
# Out:
#                                              College   Locality  \
# 0           Vignana Bharathi Institute of technology  Ghatkesar
# 1                       Aurora Group of Institutions  Ghatkesar
# 2  Vignan Institute of management and technology ...  Ghatkesar
# 3  Princeton Institute of engineering and technology  Ghatkesar
# 4              Nalla Malla Reddy Engineering College  Ghatkesar
#
#              District  latitude  longitude
# 0  Medchal-Malkajgiri   17.3535    78.2402
# 1  Medchal-Malkajgiri   17.3535    78.2402
# 2  Medchal-Malkajgiri   17.3535    78.2402
# 3  Medchal-Malkajgiri   17.3535    78.2402
# 4  Medchal-Malkajgiri   17.3535    78.2402

# %%
address = 'Hyderabad, IN'

geolocator = Nominatim(user_agent="hyd_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Hyderabad are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Hyderabad are 17.38878595, 78.46106473453146.

# %%
# !conda install -c conda-forge folium=0.5.0 --yes 
import folium # map rendering library
# create map of Hyderabad using latitude and longitude values
map_hyderabad = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(HydCollege_Final['latitude'], HydCollege_Final['longitude'], HydCollege_Final['Locality']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_hyderabad)  
    
map_hyderabad
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge
#     certifi-2019.11.28         |   py36h9f0ad1d_1         149 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     branca-0.4.0               |             py_0          26 KB  conda-forge
#     openssl-1.1.1f             |       h516909a_0         2.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.1 MB
#
# The following NEW packages will be INSTALLED:
#
#     altair:          4.1.0-py_1        conda-forge
#     branca:          0.4.0-py_0        conda-forge
#     folium:          0.5.0-py_0        conda-forge
#     python_abi:      3.6-1_cp36m       conda-forge
#     vincent:         0.4.4-py_1        conda-forge
#
# The following packages will be UPDATED:
#
#     certifi:         2019.11.28-py36_0             --> 2019.11.28-py36h9f0ad1d_1 conda-forge
#     openssl:         1.1.1e-h7b6447c_0             --> 1.1.1f-h516909a_0         conda-forge
#
# The following packages will be DOWNGRADED:
#
#     ca-certificates: 2020.1.1-0                    --> 2019.11.28-hecc5488_0     conda-forge
#
#
# Downloading and Extracting Packages
# python_abi-3.6       | 4 KB      | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# certifi-2019.11.28   | 149 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# branca-0.4.0         | 26 KB     | ##################################### | 100%
# openssl-1.1.1f       | 2.1 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
count = HydCollege_Final['Locality'].value_counts()

# %%
print(count)
# Out:
# Ghatkesar      6
# Hyderabad      5
# Bandlaguda     4
# Saroornagar    3
# Saidabad       2
# Nampally       1
# Khairatabad    1
# Uppal          1
# Shaikpet       1
# Name: Locality, dtype: int64

# %% [markdown]
# ## Results & Discussion

# %% [markdown]
# I scrapped the web for list of engineering colleges in Hyderabad and obtained an initial list of colleges. Since the geo location codes were not available, I used pgeocode library to get geo location codes for localities and merged it with the engineering collgese list. It was found that there were 104 localities in Hyderabad and 25 localities had engineering collges.
# Based on the analysis above, it is found that the Locality of Ghatkesar has highest density of engineering colleges at 6. Thus it was suggested to set up student hostel in this locality.

# %% [markdown]
# # Conclusion

# %% [markdown]
# The purpose of the project was to find areas in Hyderabad for highest density of engineering colleges for setting up a student hostel. Initially, the geographical coordinates of the localities of hyderabad were extracted as geo codes were not directly available for engineering colleges. The dataframe of Hyderabad localities was merged with colleges list on location to get colleges geographical cordinates. The results were mapped using the folium library for visual representation. From the results, Ghatkesar locality was found to have maximum college density.
